# %%
import pandas as pd

# %%
df_buyers = pd.read_csv("./data/sharepoint/sap_buyers.csv")

# %%
df_buyers.head()
# Out:
#                      Buyer Buyer Alias  Buyer Gin        Direct Manager  \
# 0       Jacqueline Barcelo   jbarcelo2    6620447  Juan Felipe Quintero
# 1   Tatiana Castillo Casas  TCastillo2   80028257  Juan Felipe Quintero
# 2      Maria Camila Duarte    MDuarte6   80035945        Andres Noguera
# 3  Maria Alejandra Gaviria    MGaviria   80034495        Andres Noguera
# 4            Royner Romero   RRomero36   80035941        Andres Noguera
#
#     Shift  BPN_Buyer Available for Audits Workload / Availability  \
# 0  7 to 5      False                   No                      0%
# 1  7 to 5      False                   No                      0%
# 2  7 to 5      False                  Yes                    100%
# 3  9 to 7      False                  Yes                    100%
# 4  9 to 7      False                  Yes                    100%
#
#            Category Available For Urgencies  ... Pgroup Team Mapping  \
# ...

# %% [markdown]
# # Reglas para df_buyers
#
# 1.
